# %% [markdown]
# # Background
#
# Data gathered from the [NYT github page](https://github.com/nytimes/covid-19-data), [USDA](https://www.nrcs.usda.gov/wps/portal/nrcs/detail/national/home/?cid=nrcs143_013697), and the US Census [population](https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/) and [land area](https://www.census.gov/geographies/reference-files/2010/geo/state-area.html) pages.

# %% [markdown]
# ## NYT Methodology
#
# > To transform raw survey responses into county-level estimates, the survey data was weighted by age and gender, and survey respondents’ locations were approximated from their ZIP codes. Then estimates of mask-wearing were made for each census tract by taking a weighted average of the 200 nearest responses, with closer responses getting more weight in the average. These tract-level estimates were then rolled up to the county level according to each tract’s total population.
# >
# > By rolling the estimates up to counties, it reduces a lot of the random noise that is seen at the tract level. In addition, the shapes in the map are constructed from census tracts that have been merged together — this helps in displaying a detailed map, but is less useful than county-level in analyzing the data.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Helper Functions

# %%
def list_diff(list1,list2):
    '''
    Finds what is missing from, or what is different between, the two lists.
    
    return
    ------
    list_difference: list
    '''
    list_difference = {}
    
    if len(list1) > len(list2):
        bigger = list1
        smaller = list2
        small_list = 'list2'
    else:
        bigger = list2
        smaller = list1
        small_list = 'list1'
        
    for item in bigger:
        if item not in smaller:
            list_difference[item] = f'missing from {small_list}'

    return list_difference

# %% [markdown]
# # County Data

# %% [markdown]
# ## Mask Data

# %%
df_mask = pd.read_csv("data/nyt_data/mask_use_data/mask-use-by-county.csv")
df_mask.columns = df_mask.columns.str.lower()
df_mask.head()
# Out:
#    countyfp  never  rarely  sometimes  frequently  always
# 0      1001  0.053   0.074      0.134       0.295   0.444
# 1      1003  0.083   0.059      0.098       0.323   0.436
# 2      1005  0.067   0.121      0.120       0.201   0.491
# 3      1007  0.020   0.034      0.096       0.278   0.572
# 4      1009  0.053   0.114      0.180       0.194   0.459

# %% [markdown]
# ## Covid Data

# %%
county_covid = pd.read_csv("data/nyt_data/us-counties.csv",parse_dates=['date'])

# %%
county_covid = county_covid.astype({
    'county':str,
    'fips':float,
    'cases':int,
    'deaths':int
})

# %%
# Rename columns
county_covid.columns = ['date','county','state','fips','covid_cases','covid_deaths']
# Rearrange columns
county_covid = county_covid[['date','state','county','fips','covid_cases','covid_deaths']]
county_covid.head()
# Out:
#         date       state     county     fips  covid_cases  covid_deaths
# 0 2020-01-21  Washington  Snohomish  53061.0            1             0
# 1 2020-01-22  Washington  Snohomish  53061.0            1             0
# 2 2020-01-23  Washington  Snohomish  53061.0            1             0
# 3 2020-01-24    Illinois       Cook  17031.0            1             0
# 4 2020-01-24  Washington  Snohomish  53061.0            1             0

# %% [markdown]
# On a previous (now removed) merging of the NYT `df_mask` and NYT `county_covid` datasets we found that the `df_mask` dataset was missing some counties. To double check what these counties are, the [USDA link](https://www.nrcs.usda.gov/wps/portal/nrcs/detail/national/home/?cid=nrcs143_013697) was scraped for all fips, name, and state data.

# %% [markdown]
# ## What was Missing?

# %%
response = requests.get("https://www.nrcs.usda.gov/wps/portal/nrcs/detail/national/home/?cid=nrcs143_013697")
soup = BeautifulSoup(response.content)

# %%
table_tag = soup.find(class_='data')

county_scrape = pd.DataFrame(columns=['fips','county','state'])

for tr in table_tag.find_all('tr')[1:]:
    tds = tr.find_all('td')
    d = pd.DataFrame(data = {'fips':[tds[0].text], 'county':[tds[1].text], 'state':[tds[2].text]})
    county_scrape = county_scrape.append(d)

# %%
county_scrape = county_scrape.reset_index(drop=True)
county_scrape = county_scrape.astype({
    'fips':int,
    'county':str,
    'state':'category'
})

# %%
county_scrape.head()
# Out:
#    fips   county state
# 0  1001  Autauga    AL
# 1  1003  Baldwin    AL
# 2  1005  Barbour    AL
# 3  1007     Bibb    AL
# 4  1009   Blount    AL

# %%
missing = list_diff(county_scrape['county'].unique(),county_covid['county'].unique())
missing_df = pd.DataFrame.from_dict(missing,orient='index')
scraped = county_scrape.set_index('county')
missing_df = missing_df.sort_index().reset_index()
missing_from_scrape = scraped.merge(missing_df, left_on='county',right_on='index')

# %%
missing_from_scrape.groupby('state').count().sort_values('fips',ascending=False)
# Out:
#        fips  index   0
# state
# VA       41     41  41
# AK       25     25  25
# LA        9      9   9
# MO        6      6   6
# NY        4      4   4
# AS        4      4   4
# IN        4      4   4
# MD        4      4   4
# MP        3      3   3
# NE        3      3   3
# IL        3      3   3
# KS        2      2   2
# TX        2      2   2
# MT        2      2   2
# AL        2      2   2
# FL        2      2   2
# PR        2      2   2
# NM        2      2   2
# MI        2      2   2
# ND        1      1   1
# MN        1      1   1
# NV        1      1   1
# TN        1      1   1
# IA        1      1   1
# UT        1      1   1
# GU        1      1   1
# GA        1      1   1
# WI        1      1   1
# AR        1      1   1
# SC        0      0   0
# SD        0      0   0
# OK        0      0   0
# RI        0      0   0
# VI        0      0   0
# VT        0      0   0
# WA        0      0   0
# PA        0      0   0
# WV        0      0   0
# OR        0      0   0
# MS        0      0   0
# OH        0      0   0
# NJ        0      0   0
# NH        0      0   0
# NC        0      0   0
# ME        0      0   0
# MA        0      0   0
# KY        0      0   0
# ID        0      0   0
# HI        0      0   0
# DE        0      0   0
# DC        0      0   0
# CT        0      0   0
# CO        0      0   0
# CA        0      0   0
# AZ        0      0   0
# WY        0      0   0

# %% [markdown]
# The vast majority of missing counties are from Virginia and Alaska.

# %%
missing_from_scrape[(missing_from_scrape['state']=='AS') ]
# Out:
#       fips state    index                   0
# 122  60020    AS    Manua  missing from list2
# 123  60020    AS      Ofu  missing from list2
# 124  60020    AS  Olosega  missing from list2
# 125  60050    AS  Tutuila  missing from list2

# %% [markdown]
# The reasons for missing counties include:
#
# * Virginia's missing counties are all cities
# * Alaska: unclear why
# * Louisiana: unincorporated communities or parishes
# * MO: De Kalb has a population of 220, is part of St. Joseph statistical area.
# * MO: St. Francois has a population of 65k, but the county seat is in Farmington. The rest are similar, with the county seat being in another county.
# * NY: boroughs of NYC, St. Lawrence has county seat in Canton
# * AS: Indian reservation
#
# The rest of the list have 4 or less missing counties, reasons are assumed to be similar as above.

# %% [markdown]
# ## Merging Mask and County Covid Data

# %% [markdown]
# The NYT mask data is merged with the NYT-included `county_covid` dataset. This allows us to see  the number of covid cases per county, along with the reported mask use.
#
# Because `county_covid` is a timeseries, we first filter to include only the latest total cases (from August 1, 2020 onwards) and then take the mean per county. In this way we should have one row per county.

# %%
df_mask.head()
# Out:
#    countyfp  never  rarely  sometimes  frequently  always
# 0      1001  0.053   0.074      0.134       0.295   0.444
# 1      1003  0.083   0.059      0.098       0.323   0.436
# 2      1005  0.067   0.121      0.120       0.201   0.491
# 3      1007  0.020   0.034      0.096       0.278   0.572
# 4      1009  0.053   0.114      0.180       0.194   0.459

# %%
county_cases_aug_on = county_covid[county_covid['date'] > '20200801'].groupby('fips').mean().reset_index()

# %%
county_cases_aug_on
# Out:
#          fips  covid_cases  covid_deaths
# 0      1001.0  1161.857143     22.142857
# 1      1003.0  3579.142857     27.571429
# 2      1005.0   631.571429      5.357143
# 3      1007.0   432.714286      4.714286
# 4      1009.0   913.714286      3.928571
# ...       ...          ...           ...
# 3193  72151.0   121.285714      0.000000
# 3194  72153.0   241.714286      0.000000
# 3195  78010.0   296.571429      4.785714
# 3196  78020.0    19.071429      0.000000
# 3197  78030.0   254.000000      4.000000
#
# [3198 rows x 3 columns]

# %%
county_mask = county_cases_aug_on.merge(df_mask,left_on='fips',right_on='countyfp')

# %%
county_mask = county_mask[['fips', 'covid_cases', 'covid_deaths', 'never', 'rarely', 'sometimes','frequently', 'always']]
county_mask.columns = ['fips', 'covid_cases', 'covid_deaths', 'mask_never', 'mask_rarely', 'mask_sometimes','mask_frequently', 'mask_always']

# %%
county_mask.head()
# Out:
#      fips  covid_cases  covid_deaths  mask_never  mask_rarely  mask_sometimes  \
# 0  1001.0  1161.857143     22.142857       0.053        0.074           0.134
# 1  1003.0  3579.142857     27.571429       0.083        0.059           0.098
# 2  1005.0   631.571429      5.357143       0.067        0.121           0.120
# 3  1007.0   432.714286      4.714286       0.020        0.034           0.096
# 4  1009.0   913.714286      3.928571       0.053        0.114           0.180
#
#    mask_frequently  mask_always
# 0            0.295        0.444
# 1            0.323        0.436
# 2            0.201        0.491
# 3            0.278        0.572
# 4            0.194        0.459

# %% [markdown]
# So far we:
#
# * Imported and cleaned `df_mask` dataframe. It includes survey results of how often people wear masks in each county.
# * Import and cleaned the `county_covid` dataframe, then found the average for data past Aug 1, 2020. This includes total (not new) covid19 cases and deaths.
# * The two dataframes were merged into one `county_mask` dataframe. This includes all NYT data to date (Aug 16, 2020).
#
# __Problem:__
# After using the `groupby()` function all `str` type columns were removed (as you cannot take the mean of strings). We lost the county and state names, but the `fips` values remained.
#
# __Solution:__ We can merge our new `county_mask` dataset with another dataset to get these names back. Since we want to find the population per county anyways, we will use the [US Census 2019 population estimate](https://www.census.gov/data/datasets/time-series/demo/popest/2010s-counties-total.html) dataset to get county name, state name, county population, and some other variables.

# %% [markdown]
# ## County Population

# %% [markdown]
# __NOTE:__ last 6 rows of the raw excel file contain disclaimers and citing instructions

# %% [markdown]
# __NOTE:__ When shown without a date variable, county covid data from here on will reflect the mean of only "recent" (August 1, 2020 onwards) figures.

# %%
countypop = pd.read_excel('data/added_data/countypop.xlsx')
countypop.columns = countypop.columns.str.lower()

# %% [markdown]
# The following keys were provided in a separate pdf file by the US census, letting us map them for interpretation.

# %%
region_key = {
    1:'northeast',
    2:'midwest',
    3:'south',
    4:'west'
}
division_key = {
    1:'new_england',
    2:'middle_atlantic',
    3:'east_north_central',
    4:'west_north_central',
    5:'south_atlantic',
    6:'east_south_central',
    7:'west_south_central',
    8:'mountain',
    9:'pacific'
}
sumlev_key = {
    40:'state_or_equiv',
    50:'county_or_equiv'
}

# %%
# select only the columns that are relevant, which is the latest (2019) estimates
countypop = countypop[['sumlev','region','division','state','county','stname','ctyname','popestimate2019',
                       'births2019','internationalmig2019','domesticmig2019','rbirth2019','rdeath2019']]
countypop.columns = ['sumlev','region_fips','division_fips','state_fips','county_fips','state','county',
                     'population','births','intnl_migration','domestic_migration','birth_rate','death_rate']
countypop.head()
# Out:
#    sumlev  region_fips  division_fips  state_fips  county_fips    state  \
# 0      40            3              6           1            0  Alabama
# 1      50            3              6           1            1  Alabama
# 2      50            3              6           1            3  Alabama
# 3      50            3              6           1            5  Alabama
# 4      50            3              6           1            7  Alabama
#
#            county  population  births  intnl_migration  domestic_migration  \
# 0         Alabama     4903185   57313             2772                9387
# 1  Autauga County       55869     624              -16                 270
# 2  Baldwin County      223234    2304               80                5297
# 3  Barbour County       24686     256               13                -141
# 4     Bibb County       22394     240               10                  31
#
#    birth_rate  death_rate
# 0   11.707442   11.005972
# 1   11.202671    9.712572
# 2   10.446871   10.546624
# 3   10.331329   12.591307
# 4   10.723621   11.259802

# %%
# find the counties that are present in our dataset
cty_fip = county_covid[['state','county','fips']].groupby(['state','county']).mean().reset_index()
cty_fip.head()
# Out:
#      state   county    fips
# 0  Alabama  Autauga  1001.0
# 1  Alabama  Baldwin  1003.0
# 2  Alabama  Barbour  1005.0
# 3  Alabama     Bibb  1007.0
# 4  Alabama   Blount  1009.0

# %% [markdown]
# It looks like the two datasets have very similar naming styles, with the exception that the NYT `county_covid` dataset does not include the words `County` or `Parish` after each territory. These are removed from the Census dataset, along with any spaces, and then merged on relevant county and state names.

# %%
# format for merging
countypop['county'] = countypop['county'].str.replace('County','')
countypop['county'] = countypop['county'].str.replace('Parish','')
countypop['county'] = countypop['county'].str.replace(' ','')

# %%
# merge fips from covid dataset with 2019pop
cty_pop = cty_fip.merge(countypop,left_on=['state','county'],right_on=['state','county'])

# %%
cty_pop = cty_pop[['state', 'county', 'fips', 'sumlev', 'region_fips', 'division_fips',
       'population','births', 'intnl_migration', 'domestic_migration', 'birth_rate',
       'death_rate']]

# %%
cty_pop.head()
# Out:
#      state   county    fips  sumlev  region_fips  division_fips  population  \
# 0  Alabama  Autauga  1001.0      50            3              6       55869
# 1  Alabama  Baldwin  1003.0      50            3              6      223234
# 2  Alabama  Barbour  1005.0      50            3              6       24686
# 3  Alabama     Bibb  1007.0      50            3              6       22394
# 4  Alabama   Blount  1009.0      50            3              6       57826
#
#    births  intnl_migration  domestic_migration  birth_rate  death_rate
# 0     624              -16                 270   11.202671    9.712572
# 1    2304               80                5297   10.446871   10.546624
# 2     256               13                -141   10.331329   12.591307
# 3     240               10                  31   10.723621   11.259802
# 4     651                6                  59   11.263268   11.367077

# %% [markdown]
# ## Merging Mask with County Pop

# %% [markdown]
# We now have two datasets:
#
# * `county_mask` that contains all NYT data regarding covid19 cases and mask use
# * `cty_pop` that contains US Census data about the population
#
# If we can merge these dataframes, we can find out the number of cases per population and a bunch of other interesting statistics. So that's what we will do next.

# %%
list_diff(county_covid['county'].unique(),cty_pop['county'].unique())
# Out:
# {'Los Angeles': 'missing from list2',
#  'Santa Clara': 'missing from list2',
#  'San Francisco': 'missing from list2',
#  'San Diego': 'missing from list2',
#  'Salt Lake': 'missing from list2',
#  'New York City': 'missing from list2',
#  'Unknown': 'missing from list2',
#  'San Mateo': 'missing from list2',
#  'Walla Walla': 'missing from list2',
#  'Contra Costa': 'missing from list2',
#  'Fort Bend': 'missing from list2',
#  'Santa Rosa': 'missing from list2',
#  'El Paso': 'missing from list2',
#  'Santa Cruz': 'missing from list2',
#  'District of Columbia': 'missing from list2',
#  'St. Louis': 'missing from list2',
#  "Prince George's": 'missing from list2',
#  'Virginia Beach city': 'missing from list2',
#  'San Joaquin': 'missing from list2',
#  'Charles Mix': 'missing from list2',
#  'New Castle': 'missing from list2',
#  'St. Johns': 'missing from list2',
#  'St. Joseph': 'missing from list2',
#  'Santa Fe': 'missing from list2',
#  'Bon Homme': 'missing from list2',
#  'Fond du Lac': 'missing from list2',
#  'Anchorage': 'missing from list2',
#  'Palm Beach': 'missing from list2',
#  'St. Clair': 'missing from list2',
#  'Carson City': 'missing from list2',
#  'Alexandria city': 'missing from list2',
#  'James City': 'missing from list2',
#  'Prince Edward': 'missing from list2',
#  'Prince William': 'missing from list2',
#  'Grays Harbor': 'missing from list2',
#  'San Benito': 'missing from list2',
#  'Clear Creek': 'missing from list2',
#  'St. Charles': 'missing from list2',
#  'St. Tammany': 'missing from list2',
#  'Anne Arundel': 'missing from list2',
#  'Pearl River': 'missing from list2',
#  'Lewis and Clark': 'missing from list2',
#  'Silver Bow': 'missing from list2',
#  'Harrisonburg city': 'missing from list2',
#  'San Luis Obispo': 'missing from list2',
#  'New Haven': 'missing from list2',
#  'St. John the Baptist': 'missing from list2',
#  'San Bernardino': 'missing from list2',
#  'Santa Barbara': 'missing from list2',
#  'St. Bernard': 'missing from list2',
#  'Baltimore city': 'missing from list2',
#  'Fairbanks North Star Borough': 'missing from list2',
#  'Blue Earth': 'missing from list2',
#  'Ketchikan Gateway Borough': 'missing from list2',
#  'Black Hawk': 'missing from list2',
#  'East Baton Rouge': 'missing from list2',
#  'Charlottesville city': 'missing from list2',
#  'Williamsburg city': 'missing from list2',
#  'Kenai Peninsula Borough': 'missing from list2',
#  'Twin Falls': 'missing from list2',
#  'St. Louis city': 'missing from list2',
#  'New Hanover': 'missing from list2',
#  'Box Elder': 'missing from list2',
#  'Charles City': 'missing from list2',
#  'Richmond city': 'missing from list2',
#  'La Crosse': 'missing from list2',
#  'Van Buren': 'missing from list2',
#  'Indian River': 'missing from list2',
#  'St. James': 'missing from list2',
#  'St. Landry': 'missing from list2',
#  'West Baton Rouge': 'missing from list2',
#  'Cape May': 'missing from list2',
#  'San Miguel': 'missing from list2',
#  'Van Zandt': 'missing from list2',
#  'Eau Claire': 'missing from list2',
#  'New London': 'missing from list2',
#  'De Soto': 'missing from list2',
#  'Kansas City': 'missing from list2',
#  'Doña Ana': 'missing from list2',
#  'Newport News city': 'missing from list2',
#  'Norfolk city': 'missing from list2',
#  'Portsmouth city': 'missing from list2',
#  'San Juan': 'missing from list2',
#  'St. Croix': 'missing from list2',
#  'El Dorado': 'missing from list2',
#  'St. Lucie': 'missing from list2',
#  'St. Mary': 'missing from list2',
#  'Deaf Smith': 'missing from list2',
#  'Isle of Wight': 'missing from list2',
#  'Suffolk city': 'missing from list2',
#  'Jo Daviess': 'missing from list2',
#  'Rock Island': 'missing from list2',
#  'Cerro Gordo': 'missing from list2',
#  "St. Mary's": 'missing from list2',
#  'Grand Traverse': 'missing from list2',
#  'Le Sueur': 'missing from list2',
#  'St. Lawrence': 'missing from list2',
#  'Juneau City and Borough': 'missing from list2',
#  'Matanuska-Susitna Borough': 'missing from list2',
#  'La Plata': 'missing from list2',
#  'St. Martin': 'missing from list2',
#  "Queen Anne's": 'missing from list2',
#  'Big Stone': 'missing from list2',
#  'Lac qui Parle': 'missing from list2',
#  'St. Francois': 'missing from list2',
#  'Hood River': 'missing from list2',
#  'Danville city': 'missing from list2',
#  'Hot Spring': 'missing from list2',
#  'Ben Hill': 'missing from list2',
#  'Cape Girardeau': 'missing from list2',
#  'Chesapeake city': 'missing from list2',
#  'Nez Perce': 'missing from list2',
#  'Jefferson Davis': 'missing from list2',
#  'Rio Arriba': 'missing from list2',
#  'San Patricio': 'missing from list2',
#  'Tom Green': 'missing from list2',
#  'Fredericksburg city': 'missing from list2',
#  'Manassas city': 'missing from list2',
#  'La Paz': 'missing from list2',
#  'Kit Carson': 'missing from list2',
#  'Rio Grande': 'missing from list2',
#  'Des Moines': 'missing from list2',
#  'East Feliciana': 'missing from list2',
#  'Pointe Coupee': 'missing from list2',
#  'Val Verde': 'missing from list2',
#  'Hampton city': 'missing from list2',
#  'King George': 'missing from list2',
#  'Lynchburg city': 'missing from list2',
#  'Poquoson city': 'missing from list2',
#  'Prince George': 'missing from list2',
#  'Radford city': 'missing from list2',
#  'Hot Springs': 'missing from list2',
#  'West Feliciana': 'missing from list2',
#  'Bristol city': 'missing from list2',
#  'Galax city': 'missing from list2',
#  'Roanoke city': 'missing from list2',
#  'East Carroll': 'missing from list2',
#  'Van Wert': 'missing from list2',
#  'Le Flore': 'missing from list2',
#  'Hopewell city': 'missing from list2',
#  'New Kent': 'missing from list2',
#  'Red River': 'missing from list2',
#  'Otter Tail': 'missing from list2',
#  'Deer Lodge': 'missing from list2',
#  'Scotts Bluff': 'missing from list2',
#  'Fall River': 'missing from list2',
#  'San Jacinto': 'missing from list2',
#  'Manassas Park city': 'missing from list2',
#  'Winchester city': 'missing from list2',
#  'St. Francis': 'missing from list2',
#  'Grand Forks': 'missing from list2',
#  'King William': 'missing from list2',
#  'Petersburg city': 'missing from list2',
#  'St. Helena': 'missing from list2',
#  'Ste. Genevieve': 'missing from list2',
#  'Franklin city': 'missing from list2',
#  'King and Queen': 'missing from list2',
#  'Waynesboro city': 'missing from list2',
#  'Crow Wing': 'missing from list2',
#  'Yellow Medicine': 'missing from list2',
#  'Live Oak': 'missing from list2',
#  'San Augustine': 'missing from list2',
#  'Yukon-Koyukuk Census Area': 'missing from list2',
#  'Del Norte': 'missing from list2',
#  'New Madrid': 'missing from list2',
#  'Jim Wells': 'missing from list2',
#  'Palo Pinto': 'missing from list2',
#  'Salem city': 'missing from list2',
#  'Pend Oreille': 'missing from list2',
#  'Southeast Fairbanks Census Area': 'missing from list2',
#  'Las Animas': 'missing from list2',
#  'Rio Blanco': 'missing from list2',
#  'De Witt': 'missing from list2',
#  'Buena Vista city': 'missing from list2',
#  'Emporia city': 'missing from list2',
#  'Lexington city': 'missing from list2',
#  'Los Alamos': 'missing from list2',
#  'Staunton city': 'missing from list2',
#  'Petersburg Borough': 'missing from list2',
#  'Jeff Davis': 'missing from list2',
#  'West Carroll': 'missing from list2',
#  'Presque Isle': 'missing from list2',
#  'St. John': 'missing from list2',
#  'St. Thomas': 'missing from list2',
#  'Bethel Census Area': 'missing from list2',
#  'Buena Vista': 'missing from list2',
#  'Grand Isle': 'missing from list2',
#  'Oglala Lakota': 'missing from list2',
#  'White Pine': 'missing from list2',
#  'Big Horn': 'missing from list2',
#  'Colonial Heights city': 'missing from list2',
#  'Fairfax city': 'missing from list2',
#  'Prince of Wales-Hyder Census Area': 'missing from list2',
#  'Golden Valley': 'missing from list2',
#  'Box Butte': 'missing from list2',
#  'Red Lake': 'missing from list2',
#  'Falls Church city': 'missing from list2',
#  'Green Lake': 'missing from list2',
#  'Nome Census Area': 'missing from list2',
#  'Kodiak Island Borough': 'missing from list2',
#  'Mille Lacs': 'missing from list2',
#  'La Salle': 'missing from list2',
#  'Red Willow': 'missing from list2',
#  'Norton city': 'missing from list2',
#  'Jim Hogg': 'missing from list2',
#  'Sitka City and Borough': 'missing from list2',
#  'Martinsville city': 'missing from list2',
#  'Adjuntas': 'missing from list2',
#  'Aguada': 'missing from list2',
#  'Aguadilla': 'missing from list2',
#  'Aguas Buenas': 'missing from list2',
#  'Aibonito': 'missing from list2',
#  'Anasco': 'missing from list2',
#  'Arecibo': 'missing from list2',
#  'Arroyo': 'missing from list2',
#  'Barceloneta': 'missing from list2',
#  'Barranquitas': 'missing from list2',
#  'Bayamon': 'missing from list2',
#  'Cabo Rojo': 'missing from list2',
#  'Caguas': 'missing from list2',
#  'Camuy': 'missing from list2',
#  'Canovanas': 'missing from list2',
#  'Carolina': 'missing from list2',
#  'Catano': 'missing from list2',
#  'Cayey': 'missing from list2',
#  'Ceiba': 'missing from list2',
#  'Ciales': 'missing from list2',
#  'Cidra': 'missing from list2',
#  'Coamo': 'missing from list2',
#  'Comerio': 'missing from list2',
#  'Corozal': 'missing from list2',
#  'Dorado': 'missing from list2',
#  'Fajardo': 'missing from list2',
#  'Florida': 'missing from list2',
#  'Guanica': 'missing from list2',
#  'Guayama': 'missing from list2',
#  'Guayanilla': 'missing from list2',
#  'Guaynabo': 'missing from list2',
#  'Gurabo': 'missing from list2',
#  'Hatillo': 'missing from list2',
#  'Hormigueros': 'missing from list2',
#  'Humacao': 'missing from list2',
#  'Isabela': 'missing from list2',
#  'Jayuya': 'missing from list2',
#  'Juana Diaz': 'missing from list2',
#  'Juncos': 'missing from list2',
#  'Lajas': 'missing from list2',
#  'Lares': 'missing from list2',
#  'Las Marias': 'missing from list2',
#  'Las Piedras': 'missing from list2',
#  'Loiza': 'missing from list2',
#  'Luquillo': 'missing from list2',
#  'Manati': 'missing from list2',
#  'Maunabo': 'missing from list2',
#  'Mayaguez': 'missing from list2',
#  'Moca': 'missing from list2',
#  'Morovis': 'missing from list2',
#  'Naguabo': 'missing from list2',
#  'Naranjito': 'missing from list2',
#  'Orocovis': 'missing from list2',
#  'Patillas': 'missing from list2',
#  'Penuelas': 'missing from list2',
#  'Ponce': 'missing from list2',
#  'Quebradillas': 'missing from list2',
#  'Rincon': 'missing from list2',
#  'Sabana Grande': 'missing from list2',
#  'Salinas': 'missing from list2',
#  'San German': 'missing from list2',
#  'San Lorenzo': 'missing from list2',
#  'San Sebastian': 'missing from list2',
#  'Santa Isabel': 'missing from list2',
#  'Toa Alta': 'missing from list2',
#  'Toa Baja': 'missing from list2',
#  'Trujillo Alto': 'missing from list2',
#  'Utuado': 'missing from list2',
#  'Vega Alta': 'missing from list2',
#  'Vega Baja': 'missing from list2',
#  'Villalba': 'missing from list2',
#  'Yabucoa': 'missing from list2',
#  'Yauco': 'missing from list2',
#  'Valdez-Cordova Census Area': 'missing from list2',
#  'Vieques': 'missing from list2',
#  'Palo Alto': 'missing from list2',
#  'Covington city': 'missing from list2',
#  'Little River': 'missing from list2',
#  'Maricao': 'missing from list2',
#  'San Saba': 'missing from list2',
#  'Northwest Arctic Borough': 'missing from list2',
#  'North Slope Borough': 'missing from list2',
#  'Culebra': 'missing from list2',
#  'Bristol Bay Borough': 'missing from list2',
#  'Dillingham Census Area': 'missing from list2',
#  'Aleutians West Census Area': 'missing from list2',
#  'Lake and Peninsula Borough': 'missing from list2',
#  'Wrangell City and Borough': 'missing from list2',
#  'Aleutians East Borough': 'missing from list2',
#  'Haines Borough': 'missing from list2',
#  'Denali Borough': 'missing from list2',
#  'Joplin': 'missing from list2',
#  'Bear Lake': 'missing from list2',
#  'Kusilvak Census Area': 'missing from list2',
#  'Roger Mills': 'missing from list2',
#  'Saipan': 'missing from list2',
#  'Tinian': 'missing from list2',
#  'Sweet Grass': 'missing from list2',
#  'Judith Basin': 'missing from list2',
#  'Powder River': 'missing from list2',
#  'Lake of the Woods': 'missing from list2'}

# %% [markdown]
# From our list it looks like the following are not included in our `cty_pop` Census dataset, but are in the NYT `county_mask` dataset:
#
# * Cities (ex: Los Angeles, Walla Walla)
# * Commonwealth areas (ex: Saipan) are not included
# * Some counties (ex: Roger Mills County in Oklahoma)
#
# Some other areas (ex: Roger Mills County) are also not included.
#
# We will ignore these for now, but still keep them in our dataframe by doing a left merge. This will keep all rows in the `county_mask` dataframe even though they have no corresponding data in the `cty_pop` dataframe.

# %%
df_county = county_mask.merge(cty_pop, on=['fips'], how='left')

# %%
100 * (sum(df_county['population'].isna()) / df_county.shape[0])
# Out:
# 7.818007049022749

# %% [markdown]
# Approximately 8% of the NYT dataframe has no corresponding data in the Census dataframe. This is acceptable to us for now, so we will go ahead with the analysis.

# %%
df_county.head()
# Out:
#      fips  covid_cases  covid_deaths  mask_never  mask_rarely  mask_sometimes  \
# 0  1001.0  1161.857143     22.142857       0.053        0.074           0.134
# 1  1003.0  3579.142857     27.571429       0.083        0.059           0.098
# 2  1005.0   631.571429      5.357143       0.067        0.121           0.120
# 3  1007.0   432.714286      4.714286       0.020        0.034           0.096
# 4  1009.0   913.714286      3.928571       0.053        0.114           0.180
#
#    mask_frequently  mask_always    state   county  sumlev  region_fips  \
# 0            0.295        0.444  Alabama  Autauga    50.0          3.0
# 1            0.323        0.436  Alabama  Baldwin    50.0          3.0
# 2            0.201        0.491  Alabama  Barbour    50.0          3.0
# 3            0.278        0.572  Alabama     Bibb    50.0          3.0
# 4            0.194        0.459  Alabama   Blount    50.0          3.0
#
#    division_fips  population  births  intnl_migration  domestic_migration  \
# 0            6.0     55869.0   624.0            -16.0               270.0
# 1            6.0    223234.0  2304.0             80.0              5297.0
# 2            6.0     24686.0   256.0             13.0              -141.0
# 3            6.0     22394.0   240.0             10.0                31.0
# 4            6.0     57826.0   651.0              6.0                59.0
#
#    birth_rate  death_rate
# 0   11.202671    9.712572
# 1   10.446871   10.546624
# 2   10.331329   12.591307
# 3   10.723621   11.259802
# 4   11.263268   11.367077

# %% [markdown]
# We map the given keys to their appropriate values for ease of categorization in the future

# %%
df_county['region'] = df_county['region_fips'].map(region_key)
df_county['division'] = df_county['division_fips'].map(division_key)
df_county['area_type'] = df_county['sumlev'].map(sumlev_key)

# %% [markdown]
# And add some preliminary per capita calculations

# %%
df_county['cases_per_million'] = (df_county['covid_cases']/df_county['population']) * 1000000
df_county['cases_per_hthousand'] = (df_county['covid_cases']/df_county['population']) * 100000
df_county['cases_per_thousand'] = (df_county['covid_cases']/df_county['population']) * 1000
df_county['cases_per_hundred'] = (df_county['covid_cases']/df_county['population']) * 100

# %%
# rearrange the columns
df_county = df_county[['state','region', 'county', 'division', 'area_type',
                       'population', 'covid_cases', 'covid_deaths', 'cases_per_million', 'cases_per_hthousand', 
                       'cases_per_thousand', 'cases_per_hundred',
                       'mask_never', 'mask_rarely','mask_sometimes', 'mask_frequently', 'mask_always', 
                       'births','intnl_migration', 'domestic_migration', 
                       'birth_rate', 'death_rate',
                       'fips', 'sumlev', 'region_fips', 'division_fips'
                    ]]

# %%
df_county.head()
# Out:
#      state region   county            division        area_type  population  \
# 0  Alabama  south  Autauga  east_south_central  county_or_equiv     55869.0
# 1  Alabama  south  Baldwin  east_south_central  county_or_equiv    223234.0
# 2  Alabama  south  Barbour  east_south_central  county_or_equiv     24686.0
# 3  Alabama  south     Bibb  east_south_central  county_or_equiv     22394.0
# 4  Alabama  south   Blount  east_south_central  county_or_equiv     57826.0
#
#    covid_cases  covid_deaths  cases_per_million  cases_per_hthousand  ...  \
# 0  1161.857143     22.142857       20796.096992          2079.609699  ...
# 1  3579.142857     27.571429       16033.143953          1603.314395  ...
# 2   631.571429      5.357143       25584.194627          2558.419463  ...
# 3   432.714286      4.714286       19322.777785          1932.277778  ...
# 4   913.714286      3.928571       15801.097875          1580.109787  ...
#
#    mask_always  births  intnl_migration  domestic_migration  birth_rate  \
# 0        0.444   624.0            -16.0               270.0   11.202671
# 1        0.436  2304.0             80.0              5297.0   10.446871
# 2        0.491   256.0             13.0              -141.0   10.331329
# 3        0.572   240.0             10.0                31.0   10.723621
# 4        0.459   651.0              6.0                59.0   11.263268
#
#    death_rate    fips  sumlev  region_fips  division_fips
# 0    9.712572  1001.0    50.0          3.0            6.0
# 1   10.546624  1003.0    50.0          3.0            6.0
# 2   12.591307  1005.0    50.0          3.0            6.0
# 3   11.259802  1007.0    50.0          3.0            6.0
# 4   11.367077  1009.0    50.0          3.0            6.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # State Data

# %% [markdown]
# ## Covid Data

# %%
state_covid = pd.read_csv("data/nyt_data/us-states.csv",parse_dates=['date'])

# %%
state_covid = state_covid.astype({
    'state':str,
    'fips':float,
    'cases':int,
    'deaths':int
})

# %%
# Rename columns
state_covid.columns = ['date','state','state_fips','covid_cases','covid_deaths']
state_covid.head()
# Out:
#         date       state  state_fips  covid_cases  covid_deaths
# 0 2020-01-21  Washington        53.0            1             0
# 1 2020-01-22  Washington        53.0            1             0
# 2 2020-01-23  Washington        53.0            1             0
# 3 2020-01-24    Illinois        17.0            1             0
# 4 2020-01-24  Washington        53.0            1             0

# %% [markdown]
# We will do the same sort of filtering as for the county data by only including total covid cases since August 1, 2020

# %%
state_covid = state_covid[state_covid['date'] >= '20200801'].reset_index(drop=True)
state_covid = state_covid.groupby('state_fips').mean().reset_index()

# %% [markdown]
# ## Land Area

# %% [markdown]
# It would be nice to know the county and state land areas, so we can get some sort of estimate for the population density. I was unable to find information for every county, however information about state land area was found at this [US Census source](https://www.census.gov/geographies/reference-files/2010/geo/state-area.html).
#
# We will scrape and format this data to get it ready for a future merge.

# %%
response = requests.get("https://www.census.gov/geographies/reference-files/2010/geo/state-area.html")

# %%
soup = BeautifulSoup(response.content)

# %%
table_tag = soup.find('tbody')

state_land_scrape = pd.DataFrame(columns=range(1,17))

for tr in table_tag.find_all('tr')[3:]:
    tds = tr.find_all('td')
    d = {}
    for i in range(0,17):
        d[i] = [tds[i].text]
    data = pd.DataFrame.from_dict(data=d)
    state_land_scrape = state_land_scrape.append(data)

# %%
cols = ['state']
areas = ['total_area_','land_area_','total_water_area_','inland_water_area_','coastal_water_area_',
         'great_lakes_water_area_','territorial_water_area_','latitude','longitude']
for i in range(1,17):
    if (i in range(1,16)) & (i % 2 == 0):
        unit = 'sqkm'
    elif (i in range(1,16)) & (i % 2 != 0):
        unit = 'sqmi'
    if (i == 1) | (i == 2):
        cols.append(f'total_area_{unit}')
    elif (i == 3) | (i == 4):
        cols.append(f'land_area_{unit}')
    elif (i == 5) | (i == 6):
        cols.append(f'total_water_area_{unit}')
    elif (i == 7) | (i == 8):
        cols.append(f'inland_water_area_{unit}')
    elif (i == 9) | (i == 10):
        cols.append(f'coastal_water_area_{unit}')
    elif (i == 11) | (i == 12):
        cols.append(f'great_lakes_water_area_{unit}')
    elif (i == 13) | (i == 14):
        cols.append(f'territorial_water_area_{unit}')
    elif (i == 15):
        cols.append('latitude')
    elif (i == 16):
        cols.append('longitude')

# %%
state_land_scrape.columns=cols
state_land_scrape = state_land_scrape.reset_index(drop=True)
state_land_scrape = state_land_scrape.iloc[3:,:].reset_index(drop=True)

# %%
state_land_scrape.head()
# Out:
#         state total_area_sqmi total_area_sqkm land_area_sqmi land_area_sqkm  \
# 0     Alabama          52,420         135,767         50,645        131,171
# 1      Alaska         665,384       1,723,337        570,641      1,477,953
# 2     Arizona         113,990         295,234        113,594        294,207
# 3    Arkansas          53,179         137,732         52,035        134,771
# 4  California         163,695         423,967        155,779        403,466
#
#   total_water_area_sqmi total_water_area_sqkm inland_water_area_sqmi  \
# 0                 1,775                 4,597                  1,058
# 1                94,743               245,383                 19,304
# 2                   396                 1,026                    396
# 3                 1,143                 2,961                  1,143
# 4                 7,916                20,501                  2,833
#
#   inland_water_area_sqkm coastal_water_area_sqmi coastal_water_area_sqkm  \
# 0                  2,740                     517                   1,340
# 1                 49,997                  26,119                  67,647
# 2                  1,026                       —                       —
# 3                  2,961                       —                       —
# 4                  7,339                     245                     634
#
#   great_lakes_water_area_sqmi great_lakes_water_area_sqkm  \
# 0                           —                           —
# 1                           —                           —
# 2                           —                           —
# 3                           —                           —
# 4                           —                           —
#
#   territorial_water_area_sqmi territorial_water_area_sqkm     latitude  \
# 0                         199                         516  +32.7396323
# 1                      49,320                     127,739  +63.3461910
# 2                           —                           —  +34.2099643
# 3                           —                           —  +34.8955256
# 4                       4,837                      12,528  +37.1485730
#
#       longitude
# 0  -086.8434593
# 1  -152.8370679
# 2  -111.6024010
# 3  -092.4446262
# 4  -119.5406515

# %% [markdown]
# ## State Pop

# %% [markdown]
# We could just figure out the state population from the county data, but the [US census](https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/state/) has this precompiled for us.

# %%
statepop_raw = pd.read_csv('data/added_data/statepop.csv')
statepop_raw.columns = statepop_raw.columns.str.lower()

# %%
statepop_raw.head()
# Out:
#    sumlev region division  state              name  census2010pop  \
# 0      10      0        0      0     United States      308745538
# 1      20      1        0      0  Northeast Region       55317240
# 2      20      2        0      0    Midwest Region       66927001
# 3      20      3        0      0      South Region      114555744
# 4      20      4        0      0       West Region       71945553
#
#    estimatesbase2010  popestimate2010  popestimate2011  popestimate2012  ...  \
# 0          308758105        309321666        311556874        313830990  ...
# 1           55318443         55380134         55604223         55775216  ...
# 2           66929725         66974416         67157800         67336743  ...
# 3          114563030        114866680        116006522        117241208  ...
# 4           71946907         72100436         72788329         73477823  ...
#
#    rdomesticmig2019  rnetmig2011  rnetmig2012  rnetmig2013  rnetmig2014  \
# 0          0.000000     2.493773     2.682083     2.636187     2.921500
# 1         -5.254530     0.887909    -0.038355    -0.469783    -0.986097
# 2         -2.365881    -0.963930    -0.973943    -0.006924    -0.762969
# 3          3.261349     5.130513     5.850458     5.292073     6.161501
# 4          0.614245     2.723344     3.062896     3.162262     4.026429
#
#    rnetmig2015  rnetmig2016  rnetmig2017  rnetmig2018  rnetmig2019
# 0     3.260435     3.252788     2.871957     2.153911     1.818059
# 1    -2.061965    -2.490484    -1.837048    -2.134447    -2.859713
# 2    -1.388437    -1.241784    -0.557370    -0.922755    -1.111173
# 3     7.277358     7.150074     6.198168     5.225519     5.203720
# 4     4.987285     5.261078     4.021194     3.044951     2.312083
#
# [5 rows x 151 columns]

# %%
statepop = statepop_raw[['name','popestimate2019','sumlev','region','division','state']].reset_index(drop=True)
statepop.columns = ['state', 'population','sumlev','region_fips','division_fips','state_fips']

# %%
statepop.head()
# Out:
#               state  population  sumlev region_fips division_fips  state_fips
# 0     United States   328239523      10           0             0           0
# 1  Northeast Region    55982803      20           1             0           0
# 2    Midwest Region    68329004      20           2             0           0
# 3      South Region   125580448      20           3             0           0
# 4       West Region    78347268      20           4             0           0

# %%
# 0 represents territories and regions, which we are not interested in. 
# This data is also included in our county datasets.
statepop = statepop[statepop['state_fips']!=0].reset_index(drop=True)

# %%
statepop.head()
# Out:
#         state  population  sumlev region_fips division_fips  state_fips
# 0     Alabama     4903185      40           3             6           1
# 1      Alaska      731545      40           4             9           2
# 2     Arizona     7278717      40           4             8           4
# 3    Arkansas     3017804      40           3             7           5
# 4  California    39512223      40           4             9           6

# %% [markdown]
# ## Merge Land Area with State Population

# %% [markdown]
# By merging the two we can get population density data.

# %%
# Merge population with land area
statepop = statepop.merge(state_land_scrape, on='state')

# %%
statepop = statepop.replace(to_replace = '—', value = np.nan)
statepop = statepop.replace(to_replace = ',', value = '')

# %%
statepop.head()
# Out:
#         state  population  sumlev region_fips division_fips  state_fips  \
# 0     Alabama     4903185      40           3             6           1
# 1      Alaska      731545      40           4             9           2
# 2     Arizona     7278717      40           4             8           4
# 3    Arkansas     3017804      40           3             7           5
# 4  California    39512223      40           4             9           6
#
#   total_area_sqmi total_area_sqkm land_area_sqmi land_area_sqkm  ...  \
# 0          52,420         135,767         50,645        131,171  ...
# 1         665,384       1,723,337        570,641      1,477,953  ...
# 2         113,990         295,234        113,594        294,207  ...
# 3          53,179         137,732         52,035        134,771  ...
# 4         163,695         423,967        155,779        403,466  ...
#
#   inland_water_area_sqmi inland_water_area_sqkm coastal_water_area_sqmi  \
# 0                  1,058                  2,740                     517
# 1                 19,304                 49,997                  26,119
# 2                    396                  1,026                     NaN
# 3                  1,143                  2,961                     NaN
# 4                  2,833                  7,339                     245
#
#   coastal_water_area_sqkm great_lakes_water_area_sqmi  \
# 0                   1,340                         NaN
# 1                  67,647                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     634                         NaN
#
#   great_lakes_water_area_sqkm territorial_water_area_sqmi  \
# 0                         NaN                         199
# 1                         NaN                      49,320
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                       4,837
#
#   territorial_water_area_sqkm     latitude     longitude
# 0                         516  +32.7396323  -086.8434593
# 1                     127,739  +63.3461910  -152.8370679
# 2                         NaN  +34.2099643  -111.6024010
# 3                         NaN  +34.8955256  -092.4446262
# 4                      12,528  +37.1485730  -119.5406515
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Merge with State Covid Data

# %%
df_state = state_covid.merge(statepop, on='state_fips')

# %% [markdown]
# We replicate what we did to `df_county` with `df_state`

# %%
cols = ['region_fips', 'division_fips',
       'total_area_sqmi', 'total_area_sqkm', 'land_area_sqmi',
       'land_area_sqkm', 'total_water_area_sqmi', 'total_water_area_sqkm',
       'inland_water_area_sqmi', 'inland_water_area_sqkm',
       'coastal_water_area_sqmi', 'coastal_water_area_sqkm',
       'great_lakes_water_area_sqmi', 'great_lakes_water_area_sqkm',
       'territorial_water_area_sqmi', 'territorial_water_area_sqkm',
       'latitude', 'longitude']

# %%
for col in cols:
    df_state[col] = df_state[col].str.replace('X','NaN')
    df_state[col] = df_state[col].str.replace(',','')
    df_state[col] = df_state[col].astype(float)

# %%
df_state['region'] = df_state['region_fips'].map(region_key)
df_state['division'] = df_state['division_fips'].map(division_key)
df_state['area_type'] = df_state['sumlev'].map(sumlev_key)

# %% [markdown]
# And add some preliminary per capita calculations

# %%
df_state['cases_per_million'] = (df_state['covid_cases']/df_state['population']) * 1000000
df_state['cases_per_hthousand'] = (df_state['covid_cases']/df_state['population']) * 100000
df_state['cases_per_thousand'] = (df_state['covid_cases']/df_state['population']) * 1000
df_state['cases_per_hundred'] = (df_state['covid_cases']/df_state['population']) * 100

# %% [markdown]
# And rearrange the columns

# %%
df_state = df_state[['state', 'region', 'division', 'area_type','covid_cases', 'covid_deaths', 'population',
                    'cases_per_million', 'cases_per_hthousand', 'cases_per_thousand',
                    'cases_per_hundred', 'state_fips','sumlev', 'region_fips', 'division_fips', 
                    'total_area_sqmi','total_area_sqkm', 'land_area_sqmi', 'land_area_sqkm',
                    'total_water_area_sqmi', 'total_water_area_sqkm',
                    'inland_water_area_sqmi', 'inland_water_area_sqkm',
                    'coastal_water_area_sqmi', 'coastal_water_area_sqkm',
                    'great_lakes_water_area_sqmi', 'great_lakes_water_area_sqkm',
                    'territorial_water_area_sqmi', 'territorial_water_area_sqkm',
                    'latitude', 'longitude']]

# %%
df_state.head()
# Out:
#         state region            division       area_type    covid_cases  \
# 0     Alabama  south  east_south_central  state_or_equiv   99287.533333
# 1      Alaska   west             pacific  state_or_equiv    4391.066667
# 2     Arizona   west            mountain  state_or_equiv  185412.733333
# 3    Arkansas  south  west_south_central  state_or_equiv   48281.200000
# 4  California   west             pacific  state_or_equiv  560676.533333
#
#    covid_deaths  population  cases_per_million  cases_per_hthousand  \
# 0   1760.066667     4903185       20249.599665          2024.959966
# 1     23.733333      731545        6002.455989           600.245599
# 2   4099.333333     7278717       25473.271365          2547.327137
# 3    531.533333     3017804       15998.785872          1599.878587
# 4  10266.200000    39512223       14189.951634          1418.995163
#
#    cases_per_thousand  ...  inland_water_area_sqmi  inland_water_area_sqkm  \
# 0           20.249600  ...                  1058.0                  2740.0
# 1            6.002456  ...                 19304.0                 49997.0
# 2           25.473271  ...                   396.0                  1026.0
# 3           15.998786  ...                  1143.0                  2961.0
# 4           14.189952  ...                  2833.0                  7339.0
#
#    coastal_water_area_sqmi  coastal_water_area_sqkm  \
# 0                    517.0                   1340.0
# 1                  26119.0                  67647.0
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                    245.0                    634.0
#
#    great_lakes_water_area_sqmi  great_lakes_water_area_sqkm  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    territorial_water_area_sqmi  territorial_water_area_sqkm   latitude  \
# 0                        199.0                        516.0  32.739632
# 1                      49320.0                     127739.0  63.346191
# 2                          NaN                          NaN  34.209964
# 3                          NaN                          NaN  34.895526
# 4                       4837.0                      12528.0  37.148573
#
#     longitude
# 0  -86.843459
# 1 -152.837068
# 2 -111.602401
# 3  -92.444626
# 4 -119.540651
#
# [5 rows x 31 columns]

# %% [markdown]
# # Save to DB

# %% [markdown]
# Finally, both `county_covid`,`df_county`, `df_state` are saved into an sqlite database for ease of access:

# %% [markdown]
# ```python
# import sqlalchemy as sq
# location = 'sqlite:///data/nyt_covid.db'
# cnx = sq.create_engine(location)
#
# # save county time series
# county_covid.to_sql('county_covid_dates', con=cnx, if_exists='fail', index=False)
# # save county
# df_county.to_sql('county_dataset', con=cnx, if_exists='fail', index=False)
# # save state
# df_state.to_sql('state_dataset', con=cnx, if_exists='fail', index=False)
# ```

# %% [markdown]
# To access in the future we just need to run:
#
# ```python
# import pandas as pd
# import sqlalchemy as sq
#
# location = 'sqlite:///data/nyt_covid.db'
# cnx = sq.create_engine(location)
#
# county_covid = pd.read_sql_table('county_covid_dates',cnx)
# df_county = pd.read_sql_table('county_dataset',cnx)
# df_state = pd.read_sql_table('state_dataset',cnx)
# ```
